# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
X = np.arange(-10,10,1)
f_x= (3 * np.cos(X) + 4*np.sin(X))

df = pd.DataFrame({'x':X,'f(x)':f_x})
df
# Out:
#      x      f(x)
# 0  -10 -0.341130
# 1   -9 -4.381865
# 2   -8 -4.393933
# 3   -7 -0.366240
# 4   -6  3.998173
# 5   -5  4.686684
# 6   -4  1.066279
# 7   -3 -3.534458
# 8   -2 -4.885630
# 9   -1 -1.744977
# 10   0  3.000000
# 11   1  4.986791
# 12   2  2.388749
# 13   3 -2.405497
# 14   4 -4.988141
# 15   5 -2.984711
# 16   6  1.762849
# 17   7  4.889653
# 18   8  3.520933
# 19   9 -1.084917

# %%
# sns.scatterplot(x='x',y='f(x)',data=df)
plt.plot(X,f_x)
plt.grid()
plt.show()
